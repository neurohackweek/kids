# %%
import numpy as np
import os
import pandas as pd
import nibabel as nib

from bokeh.io import curdoc, output_notebook, output_file, push_notebook
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, DataRange1d, Range1d, VBox, HBox, Select
from bokeh.palettes import Blues4
from bokeh.plotting import Figure, show
from scipy.signal import savgol_filter
from ipywidgets import interact, FloatSlider

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5104662c-89a4-44d8-b18b-0c8792736ff6">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('../RESULTS/SummaryRsqs.csv')

# %%
xlabel="Motion Threshold (% bad frames)"
ylabel="Median R^2"
x='motion_thresh'
y='med_rsq'
variance='CI_95'

# %%
def get_dataset(src, samplesize, lowerage, upperage):
    src['ci'] = zip(src[y] + src[variance]/2, src[y] - src[variance]/2)
    src['ci_x'] = zip(src[x], src[x])
    df = src.loc[(src.n == int(samplesize)) & (src.age_l == int(lowerage)) & (src.age_u == int(upperage)),:].copy()
    #df = df.set_index([x])
    #df.sort_index(inplace=True)
    return ColumnDataSource(data=df)

def make_plot(source, title):
    plot = Figure(plot_width=800, plot_height=600, tools="", toolbar_location=None)
    plot.title.text = title
    colors = Blues4[0:3]

    plot.scatter(x=x, y=y, source=source)
    plot.multi_line('ci_x', 'ci', source=source)
    plot.yaxis.bounds = (0, 1)
    # fixed attributes
    plot.xaxis.axis_label = xlabel
    plot.yaxis.axis_label = ylabel
    plot.axis.major_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_style = "bold"

    return plot

def update_plot(N, min_age, max_age):
    plot.title.text = "Motion for sample size " + str(N) + ", ages " + str(min_age) + "-" + str(max_age)
    max_age=min_age+3
    src = get_dataset(df, N, min_age, max_age)
    source.data.update(src.data)
    push_notebook()
    
def getspacing(alist):
    azip=zip(alist[1:], alist[:-1])
    thediffs=[q[0]-q[1] for q in azip]
    uniquediffs=list(set(thediffs))
    nonzerodiffs=uniquediffs[uniquediffs != 0]
    if (hasattr(nonzerodiffs, '__len__')) or (isinstance(nonzerodiffs, str)):
        nonzerodiffs=-1
    return(nonzerodiffs)

#samplesize = df.n.max()
samplesize = 10
lowerage = df.age_l.min()
upperage = lowerage + 3
#upperage = df.age_u.max()

source = get_dataset(df, samplesize, lowerage, upperage)
plot = make_plot(source, "Motion for sample size " + str(samplesize) + ", ages " + str(lowerage) + "-" + str(upperage))

sampleSpacing=getspacing(df.n)

samplesize_widget = FloatSlider(min=df.n.min(), max=df.n.max(), step=10, value=samplesize)
lowerage_widget = FloatSlider(min=df.age_l.min(), max=df.age_l.max(), step=1, value=lowerage)
upperage_widget = FloatSlider(min=df.age_u.min(), max=df.age_u.max(), step=1, value=upperage)

def update_upperage_range(*args):
    #if lowerage_widget.value > upperage_widget.value:
    upperage_widget.value = lowerage_widget.value+3
lowerage_widget.observe(update_upperage_range, 'value')
def update_lowerage_range(*args):
    if upperage_widget.value < lowerage_widget.value:
        lowerage_widget.value = upperage_widget.value
upperage_widget.observe(update_lowerage_range, 'value')

show(plot, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="710e315f-2ebc-4b2d-9b7c-b134dfa85ee9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#710e315f-2ebc-4b2d-9b7c-b134dfa85ee9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a5961593-852c-424d-8997-fb50af1bde18", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("710e315f-2ebc-4b2d-9b7c-b134dfa85ee9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '710e315f-2ebc-4b2d-9b7c-b134dfa85ee9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"beeec329-5926-4d37-aac1-2ff980544ab0":{"roots":{"references":[{"attributes":{"below":[{"id":"e32f84ed-5d33-48a5-a7aa-f78d93818a87","type":"LinearAxis"}],"left":[{"id":"81f8d1dd-17a5-48ed-b702-21480c3ebe8c","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"e32f84ed-5d33-48a5-a7aa-f78d93818a87","type":"LinearAxis"},{"id":"e77d496e-4c5e-4bad-a8c6-804648014cdf","type":"Grid"},{"id":"81f8d1dd-17a5-48ed-b702-21480c3ebe8c","type":"LinearAxis"},{"id":"2f509548-620b-416a-aa3c-e1d1b7bf4b5c","type":"Grid"},{"id":"b561f70c-5060-4f52-b628-f08599acb869","type":"GlyphRenderer"},{"id":"8d2130a1-d2ba-49fb-8a3c-cadbf162e124","type":"GlyphRenderer"}],"title":{"id":"e7e459b4-8e00-4a81-b568-17d87b84a412","type":"Title"},"tool_events":{"id":"7a931a6a-a894-4193-ba11-b9ac22e0a519","type":"ToolEvents"},"toolbar":{"id":"010c1554-04a1-458a-ba61-cd38dff00c5e","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"09ab1996-1028-4fa5-a596-c4f4904fafa5","type":"DataRange1d"},"y_range":{"id":"e79d83e3-d4ec-463a-a39b-0d165fe95d58","type":"DataRange1d"}},"id":"c1541cc3-e8fd-4992-b21f-dec5ac27ee1c","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"09ab1996-1028-4fa5-a596-c4f4904fafa5","type":"DataRange1d"},{"attributes":{"data_source":{"id":"58ce1894-378b-4d65-bfcd-9b79b532fec7","type":"ColumnDataSource"},"glyph":{"id":"bab9ac73-3beb-4d1e-a95e-2efda19458e6","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ccfcc1-d73e-4a50-919f-8594284916ec","type":"MultiLine"},"selection_glyph":null},"id":"8d2130a1-d2ba-49fb-8a3c-cadbf162e124","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["ci_x","ci","age_l","index","CI_95","n","motion_thresh","age_u","med_rsq"],"data":{"CI_95":[0.426300506323,0.177660178782,0.45042540078800003,0.367288054314,0.29329301713399997],"age_l":[6.0,6.0,6.0,6.0,6.0],"age_u":[9.0,9.0,9.0,9.0,9.0],"ci":[[0.8810424692784999,0.4547419629555],[0.774814456009,0.597154277227],[0.9543645878829999,0.503939187095],[0.841591070279,0.474303015965],[0.862945303884,0.56965228675]],"ci_x":[[62.0,62.0],[2.0,2.0],[42.0,42.0],[22.0,22.0],[82.0,82.0]],"index":[346,582,591,676,795],"med_rsq":[0.667892216117,0.685984366618,0.729151887489,0.657947043122,0.716298795317],"motion_thresh":[62.0,2.0,42.0,22.0,82.0],"n":[10.0,10.0,10.0,10.0,10.0]}},"id":"58ce1894-378b-4d65-bfcd-9b79b532fec7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"58ce1894-378b-4d65-bfcd-9b79b532fec7","type":"ColumnDataSource"},"glyph":{"id":"7eb902d9-49a4-4363-a328-32e3b46ebe6c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"e924f5ef-08aa-414a-ac6e-70c365117576","type":"Circle"},"selection_glyph":null},"id":"b561f70c-5060-4f52-b628-f08599acb869","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c1541cc3-e8fd-4992-b21f-dec5ac27ee1c","subtype":"Figure","type":"Plot"},"ticker":{"id":"51223dbd-c064-4cde-a1ca-7607d7ae6ab4","type":"BasicTicker"}},"id":"e77d496e-4c5e-4bad-a8c6-804648014cdf","type":"Grid"},{"attributes":{},"id":"51223dbd-c064-4cde-a1ca-7607d7ae6ab4","type":"BasicTicker"},{"attributes":{"axis_label":"Median R^2","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","bounds":[0,1],"formatter":{"id":"925bb0c2-b5dd-46c8-9fcb-926733aede10","type":"BasicTickFormatter"},"plot":{"id":"c1541cc3-e8fd-4992-b21f-dec5ac27ee1c","subtype":"Figure","type":"Plot"},"ticker":{"id":"42d5ef9d-b8a1-4844-aaaa-99b8e072e366","type":"BasicTicker"}},"id":"81f8d1dd-17a5-48ed-b702-21480c3ebe8c","type":"LinearAxis"},{"attributes":{},"id":"925bb0c2-b5dd-46c8-9fcb-926733aede10","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"xs":{"field":"ci_x"},"ys":{"field":"ci"}},"id":"bab9ac73-3beb-4d1e-a95e-2efda19458e6","type":"MultiLine"},{"attributes":{"axis_label":"Motion Threshold (% bad frames)","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","formatter":{"id":"4df6533e-2bf7-4a96-a3a2-d4ee7c7ee863","typ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[55]</strong>&gt;</code></p>

# %%
interact(update_plot, N=samplesize_widget, min_age=lowerage_widget, max_age=upperage_widget)
