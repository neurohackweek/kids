# %%
import numpy as np
import os
import pandas as pd
import nibabel as nib

from bokeh.io import curdoc, output_notebook, output_file, push_notebook
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, DataRange1d, Range1d, VBox, HBox, Select
from bokeh.palettes import Blues4
from bokeh.plotting import Figure, show
from scipy.signal import savgol_filter
from ipywidgets import interact, FloatSlider

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09810c64-8b95-4984-9d26-c9883c3a54dd">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('../RESULTS/SummaryRsqs.csv')

# %%
xlabel="Motion Threshold (% bad frames)"
ylabel="Median R^2"
x='motion_thresh'
y='med_rsq'
variance='CI_95'

# %%
def get_dataset(src, samplesize, lowerage, upperage):
    src['ci'] = zip(src[y] + src[variance]/2, src[y] - src[variance]/2)
    src['ci_x'] = zip(src[x], src[x])
    df = src.loc[(src.n == int(samplesize)) & (src.age_l == int(lowerage)) & (src.age_u == int(upperage)),:].copy()
    #df = df.set_index([x])
    #df.sort_index(inplace=True)
    return ColumnDataSource(data=df)

def make_plot(source, title):
    plot = Figure(plot_width=800, plot_height=600, tools="", toolbar_location=None)
    plot.title.text = title
    colors = Blues4[0:3]

    plot.scatter(x=x, y=y, source=source)
    plot.multi_line('ci_x', 'ci', source=source)
    plot.yaxis.bounds = (0, 1)
    # fixed attributes
    plot.xaxis.axis_label = xlabel
    plot.yaxis.axis_label = ylabel
    plot.axis.major_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_style = "bold"

    return plot

def update_plot(N, min_age, max_age):
    plot.title.text = "Motion for sample size " + str(N) + ", ages " + str(min_age) + "-" + str(max_age)
    max_age=min_age+3
    src = get_dataset(df, N, min_age, max_age)
    source.data.update(src.data)
    push_notebook()
    
def getspacing(alist):
    azip=zip(alist[1:], alist[:-1])
    thediffs=[q[0]-q[1] for q in azip]
    uniquediffs=list(set(thediffs))
    nonzerodiffs=uniquediffs[uniquediffs != 0]
    if (hasattr(nonzerodiffs, '__len__')) or (isinstance(nonzerodiffs, str)):
        nonzerodiffs=-1
    return(nonzerodiffs)

#samplesize = df.n.max()
samplesize = 10
lowerage = df.age_l.min()
upperage = lowerage + 3
#upperage = df.age_u.max()

source = get_dataset(df, samplesize, lowerage, upperage)
plot = make_plot(source, "Motion for sample size " + str(samplesize) + ", ages " + str(lowerage) + "-" + str(upperage))

sampleSpacing=getspacing(df.n)

samplesize_widget = FloatSlider(min=df.n.min(), max=df.n.max(), step=10, value=samplesize)
lowerage_widget = FloatSlider(min=df.age_l.min(), max=df.age_l.max(), step=1, value=lowerage)
upperage_widget = FloatSlider(min=df.age_u.min(), max=df.age_u.max(), step=1, value=upperage)

def update_upperage_range(*args):
    #if lowerage_widget.value > upperage_widget.value:
    upperage_widget.value = lowerage_widget.value+3
lowerage_widget.observe(update_upperage_range, 'value')
def update_lowerage_range(*args):
    if upperage_widget.value < lowerage_widget.value:
        lowerage_widget.value = upperage_widget.value
upperage_widget.observe(update_lowerage_range, 'value')

show(plot, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="331ca9e2-0bbe-4ce9-a99c-5785c6c8aded"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#331ca9e2-0bbe-4ce9-a99c-5785c6c8aded").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("b23cba0e-e687-4cb6-939b-78e85ea53745", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("331ca9e2-0bbe-4ce9-a99c-5785c6c8aded");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '331ca9e2-0bbe-4ce9-a99c-5785c6c8aded' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"92d7fcc5-f87f-488d-a2aa-cfa673f5cd56":{"roots":{"references":[{"attributes":{"axis_label":"Median R^2","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","bounds":[0,1],"formatter":{"id":"0423f9f8-2cfe-40e3-a244-b5ae14d91da0","type":"BasicTickFormatter"},"plot":{"id":"9b86ea82-e2f4-44c7-b110-09cff1a292c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"acbb9ca2-1a36-4c74-8bbf-a23d3f6444f8","type":"BasicTicker"}},"id":"0cd81be4-1526-430e-9ee6-fb219a3e16d8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"cfbe007e-ef5d-428c-b6c4-d1eebddc28d4","type":"ColumnDataSource"},"glyph":{"id":"3b2c8a5f-9eac-458d-9039-c603ff35f9a8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"437fea9b-2f59-4734-82e0-294f1105023a","type":"Circle"},"selection_glyph":null},"id":"611d58f5-3e62-4a0d-ac4e-441b05d566db","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"41400501-d97e-4b9c-9387-e98f137752c9","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"9b86ea82-e2f4-44c7-b110-09cff1a292c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"acbb9ca2-1a36-4c74-8bbf-a23d3f6444f8","type":"BasicTicker"}},"id":"f6fcacfa-c1f2-428e-ba29-95e1656abd3e","type":"Grid"},{"attributes":{},"id":"32384807-24d1-44b3-a05e-e1d5da3dcf9d","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"9743f7ae-5628-4219-8b31-f34146076291","type":"Toolbar"},{"attributes":{"data_source":{"id":"cfbe007e-ef5d-428c-b6c4-d1eebddc28d4","type":"ColumnDataSource"},"glyph":{"id":"35ef6017-a657-4871-a215-34cfc21f79aa","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"8f6c95b4-7c1f-4a21-8fe9-e5aab265b70c","type":"MultiLine"},"selection_glyph":null},"id":"5869ce65-6d63-47fe-886d-f2807771c72d","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"motion_thresh"},"y":{"field":"med_rsq"}},"id":"3b2c8a5f-9eac-458d-9039-c603ff35f9a8","type":"Circle"},{"attributes":{},"id":"cfe499d4-8aed-4598-b5f6-f051c77f7c4c","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"motion_thresh"},"y":{"field":"med_rsq"}},"id":"437fea9b-2f59-4734-82e0-294f1105023a","type":"Circle"},{"attributes":{},"id":"acbb9ca2-1a36-4c74-8bbf-a23d3f6444f8","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"xs":{"field":"ci_x"},"ys":{"field":"ci"}},"id":"35ef6017-a657-4871-a215-34cfc21f79aa","type":"MultiLine"},{"attributes":{"axis_label":"Motion Threshold (% bad frames)","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","formatter":{"id":"32384807-24d1-44b3-a05e-e1d5da3dcf9d","type":"BasicTickFormatter"},"plot":{"id":"9b86ea82-e2f4-44c7-b110-09cff1a292c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"d57cbc02-af73-4092-93ac-5a0c14c8c97c","type":"BasicTicker"}},"id":"2c0685b6-b32b-48be-a1c2-f2dbf2b2f214","type":"LinearAxis"},{"attributes":{"plot":{"id":"9b86ea82-e2f4-44c7-b110-09cff1a292c6","subtype":"Figure","type":"Plot"},"ticker":{"id":"d57cbc02-af73-4092-93ac-5a0c14c8c97c","type":"BasicTicker"}},"id":"695500f3-b1a4-4125-8595-0e34249cb8f0","type":"Grid"},{"attributes":{"below":[{"id":"2c0685b6-b32b-48be-a1c2-f2dbf2b2f214","type":"LinearAxis"}],"left":[{"id":"0cd81be4-1526-430e-9ee6-fb219a3e16d8","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"2c0685b6-b32b-48be-a1c2-f2dbf2b2f214","type":"LinearAxis"},{"id":"695500f3-b1a4-4125-8595-0e34249cb8f0","type":"Grid"},{"id":"0cd81be4-1526-430e-9ee6-fb219a3e16d8","type":"LinearAxis"},{"id":"f6fcacfa-c1f2-428e-ba29-95e1656abd3e","type":"Grid"},{"id":"611d58f5-3e62-4a0d-ac4e-441b05d566db","type":"GlyphRenderer"},{"id":"5869ce65-6d63-47fe-886d-f2807771c72d","type":"GlyphRenderer"}],"title":{"id":"ac3ae0a1-8550-4449-bf59-46f12532d05d","type":"Title"},"tool_events":{"id":"cfe ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[45]</strong>&gt;</code></p>

# %%
interact(update_plot, N=samplesize_widget, min_age=lowerage_widget, max_age=upperage_widget)
# Out:
# <function __main__.update_plot>
