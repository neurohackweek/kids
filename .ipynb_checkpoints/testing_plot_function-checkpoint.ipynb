# %%
import numpy as np
import os
import pandas as pd
import nibabel as nib

from bokeh.io import curdoc, output_notebook, output_file, push_notebook
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, DataRange1d, Range1d, VBox, HBox, Select
from bokeh.palettes import Blues4
from bokeh.plotting import Figure, show
from scipy.signal import savgol_filter
from ipywidgets import interact, FloatSlider

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37a990d8-658f-4715-992c-4c5dfdf861d0">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('../RESULTS/SummaryRsqs.csv')

# %%
xlabel="Motion Threshold (% bad frames)"
ylabel="Median R^2"
x='motion_thresh'
y='med_rsq'
variance='CI_95'

# %%
def get_dataset(src, samplesize, lowerage, upperage):
    src['ci'] = zip(src[y] + src[variance]/2, src[y] - src[variance]/2)
    src['ci_x'] = zip(src[x], src[x])
    df = src.loc[(src.n == int(samplesize)) & (src.age_l == int(lowerage)) & (src.age_u == int(upperage)),:].copy()
    #df = df.set_index([x])
    #df.sort_index(inplace=True)
    return ColumnDataSource(data=df)

def make_plot(source, title):
    plot = Figure(plot_width=800, plot_height=600, tools="", toolbar_location=None)
    plot.title.text = title
    colors = Blues4[0:3]

    plot.scatter(x=x, y=y, source=source)
    plot.multi_line('ci_x', 'ci', source=source)
    plot.yaxis.bounds = (0, 1)
    # fixed attributes
    plot.xaxis.axis_label = xlabel
    plot.yaxis.axis_label = ylabel
    plot.axis.major_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_size = "8pt"
    plot.axis.axis_label_text_font_style = "bold"

    return plot

def update_plot(N, min_age, max_age):
    plot.title.text = "Motion for sample size " + str(N) + ", ages " + str(min_age) + "-" + str(max_age)
    max_age=min_age+3
    src = get_dataset(df, N, min_age, max_age)
    source.data.update(src.data)
    push_notebook()
    
def getspacing(alist):
    azip=zip(alist[1:], alist[:-1])
    thediffs=[q[0]-q[1] for q in azip]
    uniquediffs=list(set(thediffs))
    nonzerodiffs=uniquediffs[uniquediffs != 0]
    if (hasattr(nonzerodiffs, '__len__')) or (isinstance(nonzerodiffs, str)):
        nonzerodiffs=-1
    return(nonzerodiffs)

#samplesize = df.n.max()
samplesize = 10
lowerage = df.age_l.min()
upperage = lowerage + 3
#upperage = df.age_u.max()

source = get_dataset(df, samplesize, lowerage, upperage)
plot = make_plot(source, "Motion for sample size " + str(samplesize) + ", ages " + str(lowerage) + "-" + str(upperage))

sampleSpacing=getspacing(df.n)

samplesize_widget = FloatSlider(min=df.n.min(), max=df.n.max(), step=10, value=samplesize)
lowerage_widget = FloatSlider(min=df.age_l.min(), max=df.age_l.max(), step=1, value=lowerage)
upperage_widget = FloatSlider(min=df.age_u.min(), max=df.age_u.max(), step=1, value=upperage)

def update_upperage_range(*args):
    #if lowerage_widget.value > upperage_widget.value:
    upperage_widget.value = lowerage_widget.value+3
lowerage_widget.observe(update_upperage_range, 'value')
def update_lowerage_range(*args):
    if upperage_widget.value < lowerage_widget.value:
        lowerage_widget.value = upperage_widget.value
upperage_widget.observe(update_lowerage_range, 'value')

show(plot, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="79f7d384-225d-4313-b48b-7e4578f40d92"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#79f7d384-225d-4313-b48b-7e4578f40d92").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2b820cd3-c527-4c64-bdcf-350d67a84912", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79f7d384-225d-4313-b48b-7e4578f40d92");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79f7d384-225d-4313-b48b-7e4578f40d92' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1ee86cdb-1ea6-4bda-9c40-66f5547edd79":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"xs":{"field":"ci_x"},"ys":{"field":"ci"}},"id":"190a462a-53a1-4486-9155-3d62aed5b756","type":"MultiLine"},{"attributes":{"axis_label":"Median R^2","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","bounds":[0,1],"formatter":{"id":"65e129f7-0fa7-4d50-a60a-7615a2011ad7","type":"BasicTickFormatter"},"plot":{"id":"0d8f2f56-23e7-46d1-9315-b0f652f6dcb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"ff1f918a-97aa-432e-8763-c6f70da8f4ec","type":"BasicTicker"}},"id":"18d5522d-16f2-4e2e-a74d-09214e803c1c","type":"LinearAxis"},{"attributes":{},"id":"2e0ad44c-bc45-4f4e-801d-93fd612974b0","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Motion for sample size 10, ages 6.0-9.0"},"id":"92cbe453-8e16-4baa-ae17-f8fc14b2ae47","type":"Title"},{"attributes":{"callback":null,"column_names":["ci_x","ci","age_l","index","CI_95","n","motion_thresh","age_u","med_rsq"],"data":{"CI_95":[0.426300506323,0.177660178782,0.45042540078800003,0.367288054314,0.29329301713399997],"age_l":[6.0,6.0,6.0,6.0,6.0],"age_u":[9.0,9.0,9.0,9.0,9.0],"ci":[[0.8810424692784999,0.4547419629555],[0.774814456009,0.597154277227],[0.9543645878829999,0.503939187095],[0.841591070279,0.474303015965],[0.862945303884,0.56965228675]],"ci_x":[[62.0,62.0],[2.0,2.0],[42.0,42.0],[22.0,22.0],[82.0,82.0]],"index":[346,582,591,676,795],"med_rsq":[0.667892216117,0.685984366618,0.729151887489,0.657947043122,0.716298795317],"motion_thresh":[62.0,2.0,42.0,22.0,82.0],"n":[10.0,10.0,10.0,10.0,10.0]}},"id":"1794254f-9785-4828-b7ec-b699102e04e3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1794254f-9785-4828-b7ec-b699102e04e3","type":"ColumnDataSource"},"glyph":{"id":"190a462a-53a1-4486-9155-3d62aed5b756","type":"MultiLine"},"hover_glyph":null,"nonselection_glyph":{"id":"136edc89-4ce9-433a-b0a2-f0b5adad9892","type":"MultiLine"},"selection_glyph":null},"id":"2a03bbaa-c080-4f44-a28d-53bb2ae14e3a","type":"GlyphRenderer"},{"attributes":{},"id":"d9680c11-9c51-46eb-a8f5-b0ebcf686bc0","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"motion_thresh"},"y":{"field":"med_rsq"}},"id":"aeb0d9d9-9ce2-461e-a6ac-b1a1db29fc61","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"ci_x"},"ys":{"field":"ci"}},"id":"136edc89-4ce9-433a-b0a2-f0b5adad9892","type":"MultiLine"},{"attributes":{},"id":"8cc561e0-948a-4f52-8c12-349e0f1de97a","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"1794254f-9785-4828-b7ec-b699102e04e3","type":"ColumnDataSource"},"glyph":{"id":"6c9b3d30-43f8-4d94-98de-fa9c44721166","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"aeb0d9d9-9ce2-461e-a6ac-b1a1db29fc61","type":"Circle"},"selection_glyph":null},"id":"0fda58fb-9e61-48f5-bf97-f176302c2836","type":"GlyphRenderer"},{"attributes":{"axis_label":"Motion Threshold (% bad frames)","axis_label_text_font_size":{"value":"8pt"},"axis_label_text_font_style":"bold","formatter":{"id":"8cc561e0-948a-4f52-8c12-349e0f1de97a","type":"BasicTickFormatter"},"plot":{"id":"0d8f2f56-23e7-46d1-9315-b0f652f6dcb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9680c11-9c51-46eb-a8f5-b0ebcf686bc0","type":"BasicTicker"}},"id":"7b8a57da-048b-46bd-98ba-1b27c1622c2d","type":"LinearAxis"},{"attributes":{"callback":null},"id":"c876a746-6de9-4d0a-a42b-48b0a1283b24","type":"DataRange1d"},{"attributes":{"callback":null},"id":"710de170-1f0b-437a-bd1d-d746599ef1b3","type":"DataRange1d"},{"attributes":{},"id":"65e129f7-0fa7-4d50-a60a-7615a2011ad7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0d8f2f56-23e7-46d1-9315-b0f652f6dcb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9680c11-9c51-46eb-a8f5-b0ebcf686bc0","type":"BasicTicker"}},"id":"e31df10e-e8aa-4841-a1af-88 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[38]</strong>&gt;</code></p>

# %%
interact(update_plot, N=samplesize_widget, min_age=lowerage_widget, max_age=upperage_widget)
# Out:
# <function __main__.update_plot>
