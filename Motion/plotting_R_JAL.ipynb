# %%
library(dplyr)
library(ggplot2)

# %%
data<-read.csv("/Users/julialeonard/Desktop/kids/Motion/RESULTS/SummaryRsqs.csv",header = TRUE, sep = ",")
head(data)
attach(data)
# Out:
#   motion_thresh   med_rsq      CI_95  n age_l age_u
# 1             2 0.6769855 0.13864358 10     6     9
# 2             2 0.6828597 0.66948021 10     7    10
# 3             2 0.6733957 0.10268172 10     8    11
# 4             2 0.7532632 0.05569640 10     9    12
# 5             2 0.7205926 0.33942809 10    10    13
# 6             2 0.7445019 0.09936685 10    11    14
# The following objects are masked from data (pos = 3):
#
#     age_l, age_u, CI_95, med_rsq, motion_thresh, n

# %% [markdown]
# Plotting!

# %%
ggplot(data, aes(x=motion_thresh, y=med_rsq, group=n, color=n))+geom_point() +scale_colour_gradientn(colours=rainbow(4))
# Out:
# plot without title

# %%
ggplot(data, aes(x=motion_thresh, y=med_rsq, group=n, color=n))+geom_line() +scale_colour_gradientn(colours=rainbow(4))
# Out:
# plot without title

# %%
ggplot(data, aes(factor(motion_thresh),med_rsq))+ geom_boxplot(aes(fill = factor(n)))
# Out:
# plot without title

# %%
ggplot(data, aes(x=motion_thresh, y=med_rsq, group=n, color=n))+geom_line()+facet_grid(~age_l)
# Out:
# plot without title

# %% [markdown]
# Show that we only have age chunks of 3 (so only 6-9, 7-10, etc)

# %%
ggplot(data, aes(x=motion_thresh, y=med_rsq, group=n, color=n))+geom_line()+facet_grid(age_u~age_l)
# Out:
# plot without title
